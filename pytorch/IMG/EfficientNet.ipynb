# %%
pip install efficientnet_pytorch
# Out:
# Collecting efficientnet_pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
# Collecting torch
#   Downloading torch-1.11.0-cp39-cp39-manylinux1_x86_64.whl (750.6 MB)
#      |████████████████████████████████| 750.6 MB 7.7 kB/s s eta 0:00:0105
# Requirement already satisfied: typing-extensions in /home/chohj/anaconda3/lib/python3.9/site-packages (from torch->efficientnet_pytorch) (3.10.0.2)
# Building wheels for collected packages: efficientnet-pytorch
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16446 sha256=661b37913d37991c641df1ec2dcbc0d0c08c350b90045ebb76e90b055231f413
#   Stored in directory: /home/chohj/.cache/pip/wheels/29/16/24/752e89d88d333af39a288421e64d613b5f652918e39ef1f8e3
# Successfully built efficientnet-pytorch
# Installing collected packages: torch, efficientnet-pytorch
# Successfully installed efficientnet-pytorch-0.7.1 torch-1.11.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from efficientnet_pytorch import EfficientNet
model = EfficientNet.from_pretrained('efficientnet-b0')

# # ... image preprocessing as in the classification example ...
# print(img.shape) # torch.Size([1, 3, 224, 224])

# features = model.extract_features(img)
# print(features.shape) # torch.Size([1, 1280, 7, 7])
# Out:
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b0-355c32eb.pth" to /home/chohj/.cache/torch/hub/checkpoints/efficientnet-b0-355c32eb.pth
#   0%|          | 0.00/20.4M [00:00<?, ?B/s]
# Loaded pretrained weights for efficientnet-b0

# %%
pip install torch
# Out:
# Requirement already satisfied: torch in /home/chohj/anaconda3/lib/python3.9/site-packages (1.11.0)
# Requirement already satisfied: typing-extensions in /home/chohj/anaconda3/lib/python3.9/site-packages (from torch) (3.10.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torchvision
# Out:
# Collecting torchvision
#   Downloading torchvision-0.12.0-cp39-cp39-manylinux1_x86_64.whl (21.0 MB)
#      |████████████████████████████████| 21.0 MB 19.1 MB/s eta 0:00:01
# Requirement already satisfied: requests in /home/chohj/anaconda3/lib/python3.9/site-packages (from torchvision) (2.26.0)
# Requirement already satisfied: torch==1.11.0 in /home/chohj/anaconda3/lib/python3.9/site-packages (from torchvision) (1.11.0)
# Requirement already satisfied: numpy in /home/chohj/anaconda3/lib/python3.9/site-packages (from torchvision) (1.20.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/chohj/anaconda3/lib/python3.9/site-packages (from torchvision) (8.4.0)
# Requirement already satisfied: typing-extensions in /home/chohj/anaconda3/lib/python3.9/site-packages (from torchvision) (3.10.0.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/chohj/anaconda3/lib/python3.9/site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/chohj/anaconda3/lib/python3.9/site-packages (from requests->torchvision) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/chohj/anaconda3/lib/python3.9/site-packages (from requests->torchvision) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/chohj/anaconda3/lib/python3.9/site-packages (from requests->torchvision) (1.26.7)
# Installing collected packages: torchvision
# Successfully installed torchvision-0.12.0
# Note: you may need to restart the kernel to use updated packages.

# %%
## 학습 코드
import numpy as np
import json
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import random

from efficientnet_pytorch import EfficientNet
model_name = 'efficientnet-b0'  # b5

image_size = EfficientNet.get_image_size(model_name)
print(image_size)
model = EfficientNet.from_pretrained(model_name, num_classes=5)
# Out:
# 224
# Loaded pretrained weights for efficientnet-b0

# %%
## 데이타 로드!!
batch_size  = 128
random_seed = 555
random.seed(random_seed)
torch.manual_seed(random_seed)

## make dataset
from torchvision import transforms, datasets
data_path = '/home/chohj/work/ex/data'  # class 별 폴더로 나누어진걸 확 가져와서 라벨도 달아준다
president_dataset = datasets.ImageFolder(
                                data_path,
                                transforms.Compose([
                                    transforms.Resize((224, 224)),
                                    transforms.ToTensor(),
                                    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
                                ]))
## data split
from sklearn.model_selection import train_test_split
from torch.utils.data import Subset
train_idx, tmp_idx = train_test_split(list(range(len(president_dataset))), test_size=0.2, random_state=random_seed)
datasets = {}
datasets['train'] = Subset(president_dataset, train_idx)
tmp_dataset       = Subset(president_dataset, tmp_idx)

val_idx, test_idx = train_test_split(list(range(len(tmp_dataset))), test_size=0.5, random_state=random_seed)
datasets['valid'] = Subset(tmp_dataset, val_idx)
datasets['test']  = Subset(tmp_dataset, test_idx)

## data loader 선언
dataloaders, batch_num = {}, {}
dataloaders['train'] = torch.utils.data.DataLoader(datasets['train'],
                                              batch_size=batch_size, shuffle=True,
                                              num_workers=2)
dataloaders['valid'] = torch.utils.data.DataLoader(datasets['valid'],
                                              batch_size=batch_size, shuffle=False,
                                              num_workers=2)
dataloaders['test']  = torch.utils.data.DataLoader(datasets['test'],
                                              batch_size=batch_size, shuffle=False,
                                              num_workers=2)
batch_num['train'], batch_num['valid'], batch_num['test'] = len(dataloaders['train']), len(dataloaders['valid']), len(dataloaders['test'])
print('batch_size : %d,  tvt : %d / %d / %d' % (batch_size, batch_num['train'], batch_num['valid'], batch_num['test']))
# Out:
# batch_size : 128,  tvt : 36 / 5 / 5

# %%
## 데이타 체크
import torchvision
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated

num_show_img = 5

class_names = {
    "0": "acs",      # "0": "안철수"
    "1": "ysy",   # "1": "윤석열"
    "2": "ljm",   # "2": "이재명"
    "3": "ljs",  # "3": "이준석"
    "4": "hjp",   # "4": "홍준표"
}

# train check
inputs, classes = next(iter(dataloaders['train']))
out = torchvision.utils.make_grid(inputs[:num_show_img])  # batch의 이미지를 오려부친다
imshow(out, title=[class_names[str(int(x))] for x in classes[:num_show_img]])
# valid check
inputs, classes = next(iter(dataloaders['valid']))
out = torchvision.utils.make_grid(inputs[:num_show_img])  # batch의 이미지를 오려부친다
imshow(out, title=[class_names[str(int(x))] for x in classes[:num_show_img]])
# test check
inputs, classes = next(iter(dataloaders['test']))
out = torchvision.utils.make_grid(inputs[:num_show_img])  # batch의 이미지를 오려부친다
imshow(out, title=[class_names[str(int(x))] for x in classes[:num_show_img]])

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    train_loss, train_acc, valid_loss, valid_acc = [], [], [], []
    
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'valid']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss, running_corrects, num_cnt = 0.0, 0, 0
            
            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                num_cnt += len(labels)
            if phase == 'train':
                scheduler.step()
            
            epoch_loss = float(running_loss / num_cnt)
            epoch_acc  = float((running_corrects.double() / num_cnt).cpu()*100)
            
            if phase == 'train':
                train_loss.append(epoch_loss)
                train_acc.append(epoch_acc)
            else:
                valid_loss.append(epoch_loss)
                valid_acc.append(epoch_acc)
            print('{} Loss: {:.2f} Acc: {:.1f}'.format(phase, epoch_loss, epoch_acc))
           
            # deep copy the model
            if phase == 'valid' and epoch_acc > best_acc:
                best_idx = epoch
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
#                 best_model_wts = copy.deepcopy(model.module.state_dict())
                print('==> best model saved - %d / %.1f'%(best_idx, best_acc))

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best valid Acc: %d - %.1f' %(best_idx, best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    torch.save(model.state_dict(), 'president_model.pt')
    print('model saved')
    return model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")  # set gpu

model = model.to(device)

criterion = nn.CrossEntropyLoss()

optimizer_ft = optim.SGD(model.parameters(), 
                         lr = 0.05,
                         momentum=0.9,
                         weight_decay=1e-4)

lmbda = lambda epoch: 0.98739
exp_lr_scheduler = optim.lr_scheduler.MultiplicativeLR(optimizer_ft, lr_lambda=lmbda)

# %%
model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc = train_model(model, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=200)
# Out:
# Epoch 0/199
# ----------
# train Loss: 1.02 Acc: 60.4
# valid Loss: 1.41 Acc: 58.2
# ==> best model saved - 0 / 58.2
# Epoch 1/199
# ----------
# train Loss: 0.48 Acc: 83.4
# valid Loss: 0.99 Acc: 71.1
# ==> best model saved - 1 / 71.1
# Epoch 2/199
# ----------
# train Loss: 0.27 Acc: 90.9
# valid Loss: 1.45 Acc: 67.3
# Epoch 3/199
# ----------
# train Loss: 0.65 Acc: 77.5
# valid Loss: 1.52 Acc: 48.2
# Epoch 4/199
# ----------
# train Loss: 0.38 Acc: 87.0
# valid Loss: 1.14 Acc: 63.2
# Epoch 5/199
# ----------
# train Loss: 0.42 Acc: 84.8
# valid Loss: 1.03 Acc: 74.1
# ==> best model saved - 5 / 74.1
# ----------
# train Loss: 0.12 Acc: 96.1
# valid Loss: 1.20 Acc: 76.4
# Epoch 40/199
# ----------
# train Loss: 0.05 Acc: 98.0
# valid Loss: 0.98 Acc: 80.9
# Epoch 41/199
# ----------
# train Loss: 0.08 Acc: 97.3
# valid Loss: 1.31 Acc: 76.6
# Epoch 42/199
# ----------
# train Loss: 0.05 Acc: 98.5
# valid Loss: 1.10 Acc: 79.8
# Epoch 43/199
# ----------
# train Loss: 0.04 Acc: 98.7
# valid Loss: 1.07 Acc: 82.1
# ==> best model saved - 43 / 82.1
# Epoch 44/199
# ----------
# train Loss: 0.03 Acc: 98.8
# valid Loss: 1.05 Acc: 82.9
# ==> best model saved - 44 / 82.9
# Epoch 45/199
# ----------
# train Loss: 0.14 Acc: 95.7
# valid Loss: 1.51 Acc: 72.7
# Epoch 46/199
# ----------
# train Loss: 0.07 Acc: 97.7
# valid Loss: 1.13 Acc: 78.6
# Epoch 47/199
# ----------
# train Loss: 0.12 Acc: 96.2
# valid Loss: 1.44 Acc: 78.4
# Epoch 48/199
# ----------
# train Loss: 0.06 Acc: 97.9
# valid Loss: 2.08 Acc: 79.6
# Epoch 49/199
# ----------
# train Loss: 0.07 Acc: 97.6
# valid Loss: 1.01 Acc: 78.8
# Epoch 50/199
# ----------
# train Loss: 0.28 Acc: 91.8
# valid Loss: 1.01 Acc: 77.3
# Epoch 51/199
# ----------
# train Loss: 0.08 Acc: 97.5
# valid Loss: 1.02 Acc: 80.2
# Epoch 52/199
# ----------
# train Loss: 0.04 Acc: 98.4
# valid Loss: 1.08 Acc: 78.6
# Epoch 53/199
# ----------
# train Loss: 0.12 Acc: 96.2
# valid Loss: 1.03 Acc: 78.9
# Epoch 54/199
# ----------
# train Loss: 0.06 Acc: 98.1
# valid Loss: 1.10 Acc: 81.2
# Epoch 55/199
# ----------
# train Loss: 0.04 Acc: 98.6
# valid Loss: 1.03 Acc: 83.0
# ==> best model saved - 55 / 83.0
# Epoch 56/199
# ----------
# train Loss: 0.03 Acc: 98.8
# valid Loss: 1.02 Acc: 82.5
# Epoch 57/199
# ----------
# train Loss: 0.04 Acc: 98.7
# valid Loss: 1.06 Acc: 83.8
# ==> best model saved - 57 / 83.8
# Epoch 58/199
# ----------
# train Loss: 0.04 Acc: 98.6
# valid Loss: 1.26 Acc: 82.3
# Epoch 59/199
# ----------
# train Loss: 0.18 Acc: 94.4
# valid Loss: 1.11 Acc: 76.4
# Epoch 60/199
# ----------
# train Loss: 0.06 Acc: 98.1
# valid Loss: 1.01 Acc: 80.2
# Epoch 61/199
# ----------
# train Loss: 0.03 Acc: 98.7
# valid Loss: 1.05 Acc: 81.6
# Epoch 62/199
# ----------
# train Loss: 0.03 Acc: 98.8
# valid Loss: 1.08 Acc: 82.9
# Epoch 63/199
# ----------
# train Loss: 0.03 Acc: 98.9
# valid Loss: 1.06 Acc: 82.5
# Epoch 64/199
# ----------
# train Loss: 0.03 Acc: 98.8
# valid Loss: 1.12 Acc: 83.2
# Epoch 65/199
# ----------
# train Loss: 0.09 Acc: 97.2
# valid Loss: 1.15 Acc: 82.0
# Epoch 66/199
# ----------
# train Loss: 0.04 Acc: 98.6
# valid Loss: 1.13 Acc: 83.0
# Epoch 67/199
# ----------
# train Loss: 0.07 Acc: 97.6
# valid Loss: 1.18 Acc: 80.4
# Epoch 68/199
# ----------
# train Loss: 0.18 Acc: 94.6
# valid Loss: 1.26 Acc: 70.9
# Epoch 69/199
# ----------
# train Loss: 0.07 Acc: 97.7
# valid Loss: 0.99 Acc: 78.4
# Epoch 70/199
# ----------
# train Loss: 0.04 Acc: 98.7
# valid Loss: 0.98 Acc: 81.1
# Epoch 71/199
# ----------
# train Loss: 0.03 Acc: 98.8
# valid Loss: 1.02 Acc: 82.5
# Epoch 72/199
# ----------
# train Loss: 0.07 Acc: 97.4
# valid Loss: 1.10 Acc: 79.1
# Epoch 73/199
# ----------
# train Loss: 0.10 Acc: 96.6
# valid Loss: 1.13 Acc: 80.2
# Epoch 74/199
# ----------
# train Loss: 0.06 Acc: 97.7
# valid Loss: 1.17 Acc: 81.6
# Epoch 75/199
# ----------
# train Loss: 0.05 Acc: 98.1
# valid Loss: 1.29 Acc: 80.5
# Epoch 76/199
# ----------
# train Loss: 0.06 Acc: 97.8
# valid Loss: 1.26 Acc: 82.1
# Epoch 77/199
# ----------
# train Loss: 0.03 Acc: 98.7
# valid Loss: 1.19 Acc: 82.3
# Epoch 78/199
# ----------
# train Loss: 0.03 Acc: 98.8
# valid Loss: 1.18 Acc: 83.2
# Epoch 79/199
# ----------
# train Loss: 0.04 Acc: 98.5
# valid Loss: 1.12 Acc: 82.1
# Epoch 80/199
# ----------
# train Loss: 0.03 Acc: 98.8
# valid Loss: 1.10 Acc: 82.5
# Epoch 81/199
# ----------
# train Loss: 0.08 Acc: 97.4
# valid Loss: 1.07 Acc: 79.1
# Epoch 82/199
# ----------
# train Loss: 0.04 Acc: 98.7
# valid Loss: 1.04 Acc: 82.0
# Epoch 83/199
# ----------
# train Loss: 0.03 Acc: 99.0
# valid Loss: 1.06 Acc: 83.0
# Epoch 84/199
# ----------
# train Loss: 0.03 Acc: 98.7
# valid Loss: 1.09 Acc: 83.2
# Epoch 85/199
# ----------
# train Loss: 0.06 Acc: 97.9
# valid Loss: 1.17 Acc: 82.3
# Epoch 86/199
# ----------
# train Loss: 0.03 Acc: 98.8
# valid Loss: 1.13 Acc: 83.4
# Epoch 87/199
# ----------
# train Loss: 0.09 Acc: 97.0
# valid Loss: 0.95 Acc: 80.7
# Epoch 88/199
# ----------
# train Loss: 0.06 Acc: 97.8
# valid Loss: 1.07 Acc: 82.7
# Epoch 89/199
# ----------
# train Loss: 0.03 Acc: 98.7
# valid Loss: 1.17 Acc: 82.3
# Epoch 90/199
# ----------
# train Loss: 0.04 Acc: 98.2
# valid Loss: 1.13 Acc: 80.4
# Epoch 91/199
# ----------
# train Loss: 0.03 Acc: 98.9
# valid Loss: 1.10 Acc: 82.1
# Epoch 92/199
# ----------
# train Loss: 0.03 Acc: 98.8
# valid Loss: 1.11 Acc: 82.0
# Epoch 93/199
# ----------
# train Loss: 0.02 Acc: 99.0
# valid Loss: 1.15 Acc: 82.9
# Epoch 94/199
# ----------
# train Loss: 0.02 Acc: 99.0
# valid Loss: 1.17 Acc: 82.1
# Epoch 95/199
# ----------
# train Loss: 0.02 Acc: 99.0
# valid Loss: 1.14 Acc: 82.5
# Epoch 96/199
# ----------
# train Loss: 0.02 Acc: 99.2
# valid Loss: 1.14 Acc: 82.9
# Epoch 97/199
# ----------
# train Loss: 0.02 Acc: 98.9
# valid Loss: 1.26 Acc: 82.7
# Epoch 98/199
# ----------
# train Loss: 0.04 Acc: 98.5
# valid Loss: 1.14 Acc: 78.9
# Epoch 99/199
# ----------
# train Loss: 0.09 Acc: 97.1
# valid Loss: 1.04 Acc: 79.8
# Epoch 100/199
# ----------
# train Loss: 0.06 Acc: 97.9
# valid Loss: 1.06 Acc: 79.3
# Epoch 101/199
# ----------
# train Loss: 0.05 Acc: 98.5
# valid Loss: 1.03 Acc: 80.4
# Epoch 102/199
# ----------
# train Loss: 0.04 Acc: 98.3
# valid Loss: 1.14 Acc: 80.4
# Epoch 103/199
# ----------
# train Loss: 0.05 Acc: 98.3
# valid Loss: 1.22 Acc: 80.5
# Epoch 104/199
# ----------
# train Loss: 0.04 Acc: 98.4
# valid Loss: 1.36 Acc: 80.9
# Epoch 105/199
# ----------
# train Loss: 0.10 Acc: 96.5
# valid Loss: 1.15 Acc: 81.8
# Epoch 106/199
# ----------
# train Loss: 0.04 Acc: 98.8
# valid Loss: 1.11 Acc: 82.3
# Epoch 107/199
# ----------
# train Loss: 0.03 Acc: 98.7
# valid Loss: 1.10 Acc: 82.9
# Epoch 108/199
# ----------
# train Loss: 0.03 Acc: 98.8
# valid Loss: 1.15 Acc: 82.7
# Epoch 109/199
# ----------
# train Loss: 0.04 Acc: 98.6
# valid Loss: 1.27 Acc: 81.1
# Epoch 110/199
# ----------
# train Loss: 0.05 Acc: 98.3
# valid Loss: 1.18 Acc: 81.8
# Epoch 111/199
# ----------
# train Loss: 0.04 Acc: 98.7
# valid Loss: 1.12 Acc: 83.8
# Epoch 112/199
# ----------
# train Loss: 0.04 Acc: 98.7
# valid Loss: 1.23 Acc: 82.7
# Epoch 113/199
# ----------
# train Loss: 0.03 Acc: 98.7
# valid Loss: 1.19 Acc: 83.0
# Epoch 114/199
# ----------
# train Loss: 0.02 Acc: 99.0
# valid Loss: 1.18 Acc: 83.8
# Epoch 115/199
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 1.22 Acc: 83.2
# Epoch 116/199
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 1.22 Acc: 82.7
# Epoch 117/199
# ----------
# train Loss: 0.02 Acc: 99.0
# valid Loss: 1.17 Acc: 83.2
# Epoch 118/199
# ----------
# train Loss: 0.03 Acc: 98.6
# valid Loss: 1.14 Acc: 82.3
# Epoch 119/199
# ----------
# train Loss: 0.06 Acc: 98.1
# valid Loss: 1.16 Acc: 80.0
# Epoch 120/199
# ----------
# train Loss: 0.06 Acc: 98.0
# valid Loss: 1.18 Acc: 77.5
# Epoch 121/199
# ----------
# train Loss: 0.03 Acc: 98.8
# valid Loss: 1.17 Acc: 78.9
# Epoch 122/199
# ----------
# train Loss: 0.05 Acc: 98.5
# valid Loss: 1.06 Acc: 79.8
# Epoch 123/199
# ----------
# train Loss: 0.04 Acc: 98.4
# valid Loss: 1.00 Acc: 82.0
# Epoch 124/199
# ----------
# train Loss: 0.03 Acc: 98.9
# valid Loss: 1.01 Acc: 83.6
# Epoch 125/199
# ----------
# train Loss: 0.03 Acc: 99.0
# valid Loss: 1.03 Acc: 83.6
# Epoch 126/199
# ----------
# train Loss: 0.04 Acc: 98.3
# valid Loss: 0.98 Acc: 82.3
# Epoch 127/199
# ----------
# train Loss: 0.04 Acc: 98.8
# valid Loss: 1.02 Acc: 81.4
# Epoch 128/199
# ----------
# train Loss: 0.03 Acc: 98.9
# valid Loss: 1.02 Acc: 83.2
# Epoch 129/199
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 1.02 Acc: 83.8
# Epoch 130/199
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 1.03 Acc: 82.7
# Epoch 131/199
# ----------
# train Loss: 0.02 Acc: 99.0
# valid Loss: 1.08 Acc: 82.5
# Epoch 132/199
# ----------
# train Loss: 0.02 Acc: 99.2
# valid Loss: 1.07 Acc: 82.3
# Epoch 133/199
# ----------
# train Loss: 0.02 Acc: 99.0
# valid Loss: 1.14 Acc: 82.3
# Epoch 134/199
# ----------
# train Loss: 0.02 Acc: 99.0
# valid Loss: 1.13 Acc: 82.7
# Epoch 135/199
# ----------
# train Loss: 0.03 Acc: 98.8
# valid Loss: 1.16 Acc: 82.1
# Epoch 136/199
# ----------
# train Loss: 0.04 Acc: 98.6
# valid Loss: 1.11 Acc: 82.0
# Epoch 137/199
# ----------
# train Loss: 0.04 Acc: 98.3
# valid Loss: 1.16 Acc: 81.6
# Epoch 138/199
# ----------
# train Loss: 0.03 Acc: 98.9
# valid Loss: 1.10 Acc: 82.9
# Epoch 139/199
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 1.13 Acc: 82.5
# Epoch 140/199
# ----------
# train Loss: 0.04 Acc: 98.2
# valid Loss: 1.37 Acc: 78.8
# Epoch 141/199
# ----------
# train Loss: 0.03 Acc: 98.8
# valid Loss: 1.15 Acc: 83.4
# Epoch 142/199
# ----------
# train Loss: 0.03 Acc: 98.6
# valid Loss: 1.14 Acc: 82.3
# Epoch 143/199
# ----------
# train Loss: 0.02 Acc: 99.0
# valid Loss: 1.10 Acc: 83.6
# Epoch 144/199
# ----------
# train Loss: 0.03 Acc: 98.8
# valid Loss: 1.07 Acc: 82.9
# Epoch 145/199
# ----------
# train Loss: 0.04 Acc: 98.5
# valid Loss: 1.02 Acc: 83.0
# Epoch 146/199
# ----------
# train Loss: 0.03 Acc: 98.8
# valid Loss: 1.03 Acc: 82.1
# Epoch 147/199
# ----------
# train Loss: 0.03 Acc: 98.9
# valid Loss: 1.06 Acc: 82.9
# Epoch 148/199
# ----------
# train Loss: 0.03 Acc: 98.9
# valid Loss: 1.12 Acc: 82.7
# Epoch 149/199
# ----------
# train Loss: 0.02 Acc: 99.0
# valid Loss: 1.10 Acc: 83.2
# Epoch 150/199
# ----------
# train Loss: 0.02 Acc: 99.0
# valid Loss: 1.10 Acc: 82.7
# Epoch 151/199
# ----------
# train Loss: 0.02 Acc: 99.2
# valid Loss: 1.14 Acc: 82.7
# Epoch 152/199
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 1.12 Acc: 82.9
# Epoch 153/199
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 1.13 Acc: 83.2
# Epoch 154/199
# ----------
# train Loss: 0.02 Acc: 99.2
# valid Loss: 1.12 Acc: 83.9
# ==> best model saved - 154 / 83.9
# Epoch 155/199
# ----------
# train Loss: 0.03 Acc: 98.7
# valid Loss: 1.13 Acc: 81.2
# Epoch 156/199
# ----------
# train Loss: 0.03 Acc: 99.0
# valid Loss: 1.10 Acc: 83.0
# Epoch 157/199
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 1.16 Acc: 80.9
# Epoch 158/199
# ----------
# train Loss: 0.02 Acc: 99.0
# valid Loss: 1.12 Acc: 83.4
# Epoch 159/199
# ----------
# train Loss: 0.02 Acc: 99.0
# valid Loss: 1.13 Acc: 81.1
# Epoch 160/199
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 1.09 Acc: 82.5
# Epoch 161/199
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 1.09 Acc: 83.8
# Epoch 162/199
# ----------
# train Loss: 0.02 Acc: 99.2
# valid Loss: 1.10 Acc: 83.9
# Epoch 163/199
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 1.12 Acc: 84.1
# ==> best model saved - 163 / 84.1
# Epoch 164/199
# ----------
# train Loss: 0.02 Acc: 99.0
# valid Loss: 1.14 Acc: 83.8
# Epoch 165/199
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 1.13 Acc: 83.6
# Epoch 166/199
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 1.14 Acc: 83.4
# Epoch 167/199
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 1.13 Acc: 83.0
# Epoch 168/199
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 1.23 Acc: 82.0
# Epoch 169/199
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 1.21 Acc: 82.5
# Epoch 170/199
# ----------
# train Loss: 0.02 Acc: 99.2
# valid Loss: 1.20 Acc: 82.7
# Epoch 171/199
# ----------
# train Loss: 0.01 Acc: 99.3
# valid Loss: 1.19 Acc: 82.5
# Epoch 172/199
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 1.20 Acc: 82.7
# Epoch 173/199
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 1.24 Acc: 82.7
# Epoch 174/199
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 1.22 Acc: 83.0
# Epoch 175/199
# ----------
# train Loss: 0.02 Acc: 99.0
# valid Loss: 1.21 Acc: 83.4
# Epoch 176/199
# ----------
# train Loss: 0.02 Acc: 99.0
# valid Loss: 1.19 Acc: 83.4
# Epoch 177/199
# ----------
# train Loss: 0.02 Acc: 99.0
# valid Loss: 1.12 Acc: 82.7
# Epoch 178/199
# ----------
# train Loss: 0.02 Acc: 99.0
# valid Loss: 1.11 Acc: 82.3
# Epoch 179/199
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 1.14 Acc: 80.7
# Epoch 180/199
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 1.13 Acc: 82.3
# Epoch 181/199
# ----------
# train Loss: 0.02 Acc: 99.0
# valid Loss: 1.14 Acc: 82.5
# Epoch 182/199
# ----------
# train Loss: 0.02 Acc: 99.0
# valid Loss: 1.17 Acc: 82.3
# Epoch 183/199
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 1.17 Acc: 81.8
# Epoch 184/199
# ----------
# train Loss: 0.02 Acc: 99.0
# valid Loss: 1.17 Acc: 82.5
# Epoch 185/199
# ----------
# train Loss: 0.02 Acc: 99.2
# valid Loss: 1.19 Acc: 81.1
# Epoch 186/199
# ----------
# train Loss: 0.03 Acc: 98.8
# valid Loss: 1.28 Acc: 80.2
# Epoch 187/199
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 1.18 Acc: 82.3
# Epoch 188/199
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 1.15 Acc: 83.2
# Epoch 189/199
# ----------
# train Loss: 0.02 Acc: 99.2
# valid Loss: 1.15 Acc: 83.2
# Epoch 190/199
# ----------
# train Loss: 0.02 Acc: 99.0
# valid Loss: 1.16 Acc: 83.2
# Epoch 191/199
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 1.16 Acc: 83.8
# Epoch 192/199
# ----------
# train Loss: 0.02 Acc: 99.0
# valid Loss: 1.15 Acc: 82.5
# Epoch 193/199
# ----------
# train Loss: 0.02 Acc: 99.2
# valid Loss: 1.13 Acc: 83.9
# Epoch 194/199
# ----------
# train Loss: 0.02 Acc: 98.9
# valid Loss: 1.20 Acc: 83.6
# Epoch 195/199
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 1.21 Acc: 82.7
# Epoch 196/199
# ----------
# train Loss: 0.02 Acc: 99.2
# valid Loss: 1.18 Acc: 83.4
# Epoch 197/199
# ----------
# train Loss: 0.02 Acc: 99.0
# valid Loss: 1.18 Acc: 83.2
# Epoch 198/199
# ----------
# train Loss: 0.02 Acc: 99.2
# valid Loss: 1.17 Acc: 83.8
# Epoch 199/199
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 1.15 Acc: 84.5
# ==> best model saved - 199 / 84.5
# Training complete in 43m 22s
# Best valid Acc: 199 - 84.5
# model saved

# %%
## 결과 그래프 그리기
print('best model : %d - %1.f / %.1f'%(best_idx, valid_acc[best_idx], valid_loss[best_idx]))
fig, ax1 = plt.subplots()

ax1.plot(train_acc, 'b-')
ax1.plot(valid_acc, 'r-')
plt.plot(best_idx, valid_acc[best_idx], 'ro')
ax1.set_xlabel('epoch')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('acc', color='k')
ax1.tick_params('y', colors='k')

ax2 = ax1.twinx()
ax2.plot(train_loss, 'g-')
ax2.plot(valid_loss, 'k-')
plt.plot(best_idx, valid_loss[best_idx], 'ro')
ax2.set_ylabel('loss', color='k')
ax2.tick_params('y', colors='k')

fig.tight_layout()
plt.show()
# Out:
# best model : 199 - 84 / 1.2

# %%
def test_and_visualize_model(model, phase = 'test', num_images=4):
    # phase = 'train', 'valid', 'test'
    
    was_training = model.training
    model.eval()
    fig = plt.figure()
    
    running_loss, running_corrects, num_cnt = 0.0, 0, 0

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders[phase]):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)  # batch의 평균 loss 출력

            running_loss    += loss.item() * inputs.size(0)
            running_corrects+= torch.sum(preds == labels.data)
            num_cnt += inputs.size(0)  # batch size

    #         if i == 2: break

        test_loss = running_loss / num_cnt
        test_acc  = running_corrects.double() / num_cnt       
        print('test done : loss/acc : %.2f / %.1f' % (test_loss, test_acc*100))

    # 예시 그림 plot
    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders[phase]):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)        

            # 예시 그림 plot
            for j in range(1, num_images+1):
                ax = plt.subplot(num_images//2, 2, j)
                ax.axis('off')
                ax.set_title('%s : %s -> %s'%(
                    'True' if class_names[str(labels[j].cpu().numpy())]==class_names[str(preds[j].cpu().numpy())] else 'False',
                    class_names[str(labels[j].cpu().numpy())], class_names[str(preds[j].cpu().numpy())]))
                imshow(inputs.cpu().data[j])          
            if i == 0 : break


    model.train(mode=was_training);  # 다시 train모드로
    
## TEST!
test_and_visualize_model(model, phase = 'test')
# Out:
# test done : loss/acc : 1.00 / 85.2
